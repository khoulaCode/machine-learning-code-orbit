# %%
import numpy as np

# %%
import numpy as np

# Create a 10x10 image with random pixel values (0-255)
image = np.random.randint(0, 256, (10, 10))
print("Original Image:\n", image)
# Out:
# Original Image:
#  [[ 46 154  24  97 130  87  61 177 147  70]
#  [189  89 135 241  18 138  70  22 147  81]
#  [231  26 226 178 246  21  31  57 237 246]
#  [201  70 146  73 101  27 104  73 164  84]
#  [227 174 198  38 126 238  69  10 209  26]
#  [237  12  46 128 149  60  17 109 213 183]
#  [125 109 152 146  29 190  67  83 125 225]
#  [ 97  53  46 106 127  17  95 202 249 156]
#  [ 32 154  91 233 160  17  63 167  22 147]
#  [131  64 189  83 177  40 176 157  23 114]]

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np

image = np.random.randint(0, 256, (10, 10))  # Example grayscale image
plt.imshow(image, cmap='gray')
plt.title("Grayscale Image")
plt.colorbar()
plt.show()

# %%
inverted_image = 255 - image
print("Inverted Image:\n", inverted_image)
# Out:
# Inverted Image:
#  [[ 69  58 225 161 199   9 150  16 149 128]
#  [187 165 139  98  23 129 239 252 250 227]
#  [ 13 185 191 101  10 180  40 230 130 248]
#  [208  66   4 195  95  19 146  44  38 164]
#  [244 186 139  69 175 165  82 139 131  63]
#  [ 85 201 210  37  16  61 226 225  59  46]
#  [102 233 166 132  35 223  53 114 233 137]
#  [100 117 149   4  27  35 128  85 186 243]
#  [196 109 141  35 211  79 179 237 172   5]
#  [137 122  56 181 195 218  57  85 174 146]]

# %%
threshold = 128
thresholded_image = np.where(image < threshold, 0, 255)
print("Thresholded Image:\n", thresholded_image)
# Out:
# Thresholded Image:
#  [[255 255   0   0   0 255   0 255   0   0]
#  [  0   0   0 255 255   0   0   0   0   0]
#  [255   0   0 255 255   0 255   0   0   0]
#  [  0 255 255   0 255 255   0 255 255   0]
#  [  0   0   0 255   0   0 255   0   0 255]
#  [255   0   0 255 255 255   0   0 255 255]
#  [255   0   0   0 255   0 255 255   0   0]
#  [255 255   0 255 255 255   0 255   0   0]
#  [  0 255   0 255   0 255   0   0   0 255]
#  [  0 255 255   0   0   0 255 255   0   0]]

# %%
cropped_image = image[3:7, 3:7]
print("Cropped 4x4 Region:\n", cropped_image)
# Out:
# Cropped 4x4 Region:
#  [[ 60 160 236 109]
#  [186  80  90 173]
#  [218 239 194  29]
#  [123 220  32 202]]

# %%
edge_image = np.zeros_like(image)

for i in range(image.shape[0]):
    for j in range(image.shape[1] - 1):
        edge_image[i, j] = image[i, j+1] - image[i, j]

print("Simple Edge Detection:\n", edge_image)
# Out:
# Simple Edge Detection:
#  [[  11 -167   64  -38  190 -141  134 -133   21    0]
#  [  22   26   41   75 -106 -110  -13    2   23    0]
#  [-172   -6   90   91 -170  140 -190  100 -118    0]
#  [ 142   62 -191  100   76 -127  102    6 -126    0]
#  [  58   47   70 -106   10   83  -57    8   68    0]
#  [-116   -9  173   21  -45 -165    1  166   13    0]
#  [-131   67   34   97 -188  170  -61 -119   96    0]
#  [ -17  -32  145  -23   -8  -93   43 -101  -57    0]
#  [  87  -32  106 -176  132 -100  -58   65  167    0]
#  [  15   66 -125  -14  -23  161  -28  -89   28    0]]
