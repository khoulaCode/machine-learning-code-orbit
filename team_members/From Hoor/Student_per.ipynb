# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
path= r"C:\Users\admin\Desktop\Machine Learning\machine-learning-code-orbit\team_members\From Hoor\Data1\archive (3)\Student_Performance.csv"
df= pd.read_csv(path, sep = ';')
df
# Out:
#      Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index
# 0                                     7,99,Yes,9,1,91.0
# 1                                      4,82,No,4,2,65.0
# 2                                     8,51,Yes,7,2,45.0
# 3                                     5,52,Yes,5,2,36.0
# 4                                      7,75,No,8,5,66.0
# ...                                                 ...
# 9995                                  1,49,Yes,4,2,23.0
# 9996                                  7,64,Yes,8,5,58.0
# 9997                                  6,83,Yes,8,5,74.0
# 9998                                  9,97,Yes,7,0,95.0
# 9999                                   7,74,No,8,1,64.0
#
# [10000 rows x 1 columns]

# %%
print("Dataset shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())
print("\nData types:\n", df.dtypes)
print("\nStatistical Summary:\n", df.describe())
# Out:
# Dataset shape: (10000, 1)
#
# Missing values:
#  Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index    0
# dtype: int64
#
# Data types:
#  Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index    object
# dtype: object
#
# Statistical Summary:
#         Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index
# count                                               10000
# unique                                               9873
# top                                     5,59,Yes,9,0,45.0
# freq                                                    3

# %% [markdown]
# ## Preprocessing

# %%
#Encode categorical variables
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index_1,40,No,4,8,12.0  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index_1,40,No,5,6,13.0  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index_1,40,No,5,9,10.0  \
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index_1,40,No,4,8,12.0  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index_1,40,No,5,6,13.0  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index_1,40,No,5,9,10.0  \
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index  10000 non-null  object
# dtypes: object(1)
# memory usage: 78.3+ KB

# %%
df.columns
# Out:
# Index(['Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index'], dtype='object')

# %%
df.head()
# Out:
#   Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index
# 0                                  7,99,Yes,9,1,91.0
# 1                                   4,82,No,4,2,65.0
# 2                                  8,51,Yes,7,2,45.0
# 3                                  5,52,Yes,5,2,36.0
# 4                                   7,75,No,8,5,66.0

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index]
# Index: []

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index]
# Index: []

# %%
df.isnull().sum()
# Out:
# Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index    0
# dtype: int64

# %%
df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\admin\AppData\Local\Temp\ipykernel_21476\901282791.py:1: SyntaxWarning: invalid escape sequence '\?'
#   df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Empty DataFrame
# Columns: [Hours Studied,Previous Scores,Extracurricular Activities,Sleep Hours,Sample Question Papers Practiced,Performance Index]
# Index: []

# %%
df.to_csv('clean.csv')
df.head()
# Out:
#    Hours_Studied  Previous_Scores  Sleep_Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample_Question_Papers_Practiced  Performance_Index  \
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
#
#    Extracurricular_Activities_Yes
# 0                            True
# 1                           False
# 2                            True
# 3                            True
# 4                           False

# %% [markdown]
# ## Data Overview

# %%
df.isnull().sum()
# Out:
# Hours_Studied                       0
# Previous_Scores                     0
# Sleep_Hours                         0
# Sample_Question_Papers_Practiced    0
# Performance_Index                   0
# Extracurricular_Activities_Yes      0
# dtype: int64

# %% [markdown]
# ## Check for Missing Values

# %%
df.duplicated().sum()
# Out:
# np.int64(127)

# %% [markdown]
# ## Check for Duplicate Rows

# %%
df.shape
# Out:
# (10000, 6)

# %% [markdown]
# ## Preview the Data

# %%
df.corr()
# Out:
#                                   Hours_Studied  Previous_Scores  Sleep_Hours  \
# Hours_Studied                          1.000000        -0.012390     0.001245
# Previous_Scores                       -0.012390         1.000000     0.005944
# Sleep_Hours                            0.001245         0.005944     1.000000
# Sample_Question_Papers_Practiced       0.017463         0.007888     0.003990
# Performance_Index                      0.373730         0.915189     0.048106
# Extracurricular_Activities_Yes         0.003873         0.008369    -0.023284
#
#                                   Sample_Question_Papers_Practiced  \
# Hours_Studied                                             0.017463
# Previous_Scores                                           0.007888
# Sleep_Hours                                               0.003990
# Sample_Question_Papers_Practiced                          1.000000
# Performance_Index                                         0.043268
# ...

# %% [markdown]
# ## Scalling

# %%
X = df.drop('Performance Index', axis=1)
y = df['Performance Index']

# %% [markdown]
# ## Split Data into Training and Testing Sets

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# ## Initialize Linear Regression Model

# %%
regressor.fit(X_train,y_train)

# %% [markdown]
# ## Train Linear Regression Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Predict and Prepare for Evaluation

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("--- Linear Regression Results ---")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2): {r2:.2f}")

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.title('Linear Regression Predicted Performance Index')
plt.xlabel('Actual Performance Index')
plt.ylabel('Predicted Performance Index')
plt.grid()
plt.show()
