# %%
import pandas as pd 

import matplotlib.pyplot as plt

# %%
path= r"C:\Users\admin\OneDrive\Desktop\machine-learning-code-orbit\From_Aya\data\household_power_consumption.txt"
df= pd.read_csv(path, sep=";" )
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7480\2669204348.py:2: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(path, sep=";" )
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# ...

# %%
# Reload the dataframe with the correct separator
df = pd.read_csv(path, sep=";")

# Combine Date and Time columns into a Datetime column
df["Datetime"] = pd.to_datetime(
    df["Date"] + " " + df["Time"],
    format="%d/%m/%Y %H:%M:%S"
)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7480\3723256498.py:2: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=";")

# %%
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
# Data for January 2007
january_2007 = df[(df["Datetime"] >= "2007-01-01") & (df["Datetime"] < "2007-02-01")]
january_2007.head()
# Out:
#            Date      Time Global_active_power Global_reactive_power  Voltage  \
# 21996  1/1/2007  00:00:00               2.580                 0.136  241.970
# 21997  1/1/2007  00:01:00               2.552                 0.100  241.750
# 21998  1/1/2007  00:02:00               2.550                 0.100  241.640
# 21999  1/1/2007  00:03:00               2.550                 0.100  241.710
# 22000  1/1/2007  00:04:00               2.554                 0.100  241.980
#
#       Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3  \
# 21996           10.600          0.000          0.000             0.0
# 21997           10.400          0.000          0.000             0.0
# 21998           10.400          0.000          0.000             0.0
# 21999           10.400          0.000          0.000             0.0
# 22000           10.400          0.000          0.000             0.0
#
#                  Datetime
# 21996 2007-01-01 00:00:00
# 21997 2007-01-01 00:01:00
# ...

# %%
# Data for a specific day
day_data = df[df["Datetime"].dt.date == pd.to_datetime("2007-01-15").date()]
day_data.head()
# Out:
#             Date      Time Global_active_power Global_reactive_power  Voltage  \
# 42156  15/1/2007  00:00:00               1.382                 0.104  242.120
# 42157  15/1/2007  00:01:00               1.358                 0.100  241.700
# 42158  15/1/2007  00:02:00               1.352                 0.096  241.030
# 42159  15/1/2007  00:03:00               1.356                 0.098  241.280
# 42160  15/1/2007  00:04:00               1.360                 0.100  241.870
#
#       Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3  \
# 42156            5.600          0.000          0.000            18.0
# 42157            5.600          0.000          0.000            17.0
# 42158            5.600          0.000          0.000            18.0
# 42159            5.600          0.000          0.000            18.0
# 42160            5.600          0.000          0.000            18.0
#
#                  Datetime
# 42156 2007-01-15 00:00:00
# 42157 2007-01-15 00:01:00
# ...

# %%
df['Global_active_power']
# Out:
# 0          4.216
# 1          5.360
# 2          5.374
# 3          5.388
# 4          3.666
#            ...
# 2075254    0.946
# 2075255    0.944
# 2075256    0.938
# 2075257    0.934
# 2075258    0.932
# Name: Global_active_power, Length: 2075259, dtype: object

# %%
# Weekly average consumption using the daily series
weekly = daily.resample('W').mean()
weekly.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Weekly average consumption using the daily series
# ----> 2 weekly = daily.resample('W').mean()
#       3 weekly.head()
#
# NameError: name 'daily' is not defined

# %%
# Monthly average consumption using the daily series
monthly = daily.resample('M').mean()
monthly.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8904\1781487374.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = daily.resample('M').mean()
# Datetime
# 2006-12-31    1.953445
# 2007-01-31    1.546060
# 2007-02-28    1.401130
# 2007-03-31    1.318649
# 2007-04-30    0.894376
# Freq: ME, Name: Global_active_power, dtype: float64

# %%
# Convert 'Global_active_power' to numeric, coerce errors to NaN
df['Global_active_power'] = pd.to_numeric(df['Global_active_power'], errors='coerce')

# Create a daily time series of mean Global_active_power
daily = df.set_index('Datetime')['Global_active_power'].resample('D').mean()

# Resample to monthly average
monthly = daily.resample('M').mean()

# Plot the monthly average
monthly.plot(title='Monthly Global Active Power')
plt.xlabel('Month')
plt.ylabel('Power (kilowatts)')
plt.grid(True)
plt.show() # type: ignore
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7480\2634711788.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = daily.resample('M').mean()
