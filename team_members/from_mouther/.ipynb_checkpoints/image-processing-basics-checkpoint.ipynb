# %%
import numpy as np

# %%
image = np.random.randint(0, 256, (10, 10))
print(image)
# Out:
# [[ 43 193  26  20 157  72  64 224   3 236]
#  [ 12  89 173 222 254 246  43 223  22  40]
#  [112 179 215  28 102 230 151 162 200 242]
#  [222 154 122  10  98 186  70  39  41 232]
#  [177 177  39   5 125  54  28  29 106  75]
#  [ 49  97  61  84  56  50  68 150 204 232]
#  [109 112  74  12 236  24 158  59 245 134]
#  [175 126 249  98  36 204  92 149 103 233]
#  [152 132  59  75 184 226  19  62 240  81]
#  [253  61 146 130 164  35 214 149  36  94]]

# %%
import matplotlib.pyplot as plt
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# </p1> matplotlib.pyplot.imshow() allows you to render an arry as an image, since it's gray scale we have to specify the colormap "gray" then we can display the image using plt.show() <p1/>

# %%
inv_image = 255 - image
plt.imshow(inv_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
threshold = 128
thresholded_image = (image > threshold).astype(np.uint8) * 255
plt.imshow(thresholded_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
crop_image = image[2:6, 2:6]
plt.imshow(crop_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
h_edges = np.zeros_like(image)
h_edges[:, :-1] = image[:, 1:] - image[:, :-1]
plt.imshow(h_edges, cmap='gray')
plt.axis('off')
plt.show()
