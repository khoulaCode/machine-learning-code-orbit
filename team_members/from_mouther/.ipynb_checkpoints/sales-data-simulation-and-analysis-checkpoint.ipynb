# %%
import numpy as np

# %%
sales = np.random.normal(100, 1000, size=30)
sales = np.round(sales, 2)
sales = np.clip(sales, 0, None)
print("Sales data for the month: ", sales)
# Out:
# Sales data for the month:  [ 689.97    0.      0.   1649.32    0.      0.      0.      0.    797.54
#   410.76  316.37  292.53    0.    640.44  419.01  136.51  421.25 1442.17
#     0.     14.48  190.37    0.    474.79    0.      0.      0.    622.65
#     0.      0.      0.  ]

# %%
units_sold = np.random.randint(1, 100, size=30)
print("Units sold for the month: ", units_sold)
# Out:
# Units sold for the month:  [53  8 82 83 82 76 73 91 24 71 25 13  1 67 85 47 97 86 74 61 91 55 31 20
#  26 33 79 72 57 85]

# %%
sales_revenue = sales * units_sold
print("Sales revenue for the month: ", sales_revenue)
# Out:
# Sales revenue for the month:  [ 36568.41      0.        0.   136893.56      0.        0.        0.
#       0.    19140.96  29163.96   7909.25   3802.89      0.    42909.48
#   35615.85   6415.97  40861.25 124026.62      0.      883.28  17323.67
#       0.    14718.49      0.        0.        0.    49189.35      0.
#       0.        0.  ]

# %%
data_2dim = np.column_stack((sales_revenue, units_sold))
print(data_2dim)
# Out:
# [[3.6568410e+04 5.3000000e+01]
#  [0.0000000e+00 8.0000000e+00]
#  [0.0000000e+00 8.2000000e+01]
#  [1.3689356e+05 8.3000000e+01]
#  [0.0000000e+00 8.2000000e+01]
#  [0.0000000e+00 7.6000000e+01]
#  [0.0000000e+00 7.3000000e+01]
#  [0.0000000e+00 9.1000000e+01]
#  [1.9140960e+04 2.4000000e+01]
#  [2.9163960e+04 7.1000000e+01]
#  [7.9092500e+03 2.5000000e+01]
#  [3.8028900e+03 1.3000000e+01]
#  [0.0000000e+00 1.0000000e+00]
#  [4.2909480e+04 6.7000000e+01]
#  [3.5615850e+04 8.5000000e+01]
#  [6.4159700e+03 4.7000000e+01]
#  [4.0861250e+04 9.7000000e+01]
#  [1.2402662e+05 8.6000000e+01]
#  [0.0000000e+00 7.4000000e+01]
#  [8.8328000e+02 6.1000000e+01]
#  [1.7323670e+04 9.1000000e+01]
#  [0.0000000e+00 5.5000000e+01]
#  [1.4718490e+04 3.1000000e+01]
#  [0.0000000e+00 2.0000000e+01]
#  [0.0000000e+00 2.6000000e+01]
#  [0.0000000e+00 3.3000000e+01]
#  [4.9189350e+04 7.9000000e+01]
#  [0.0000000e+00 7.2000000e+01]
#  [0.0000000e+00 5.7000000e+01]
#  [0.0000000e+00 8.5000000e+01]]

# %%
total_sales = np.sum(sales_revenue) 
print(f"Total sales revenue for the month: {total_sales:.2f}")
# Out:
# Total sales revenue for the month: 565422.99

# %%
average_sales = np.mean(units_sold)
average_sales = np.round(average_sales, 0)
average_sales = int(average_sales)
print(f"Average sales units_sold for the month: {average_sales}")
# Out:
# Average sales units_sold for the month: 58

# %%
maximum_sales = np.max(sales_revenue)
maximum_sales_index = np.argmax(sales_revenue)
print(f"Maximum sales revenue of {maximum_sales:.2f} occurred at index {maximum_sales_index}.")
# Out:
# Maximum sales revenue of 136893.56 occurred at index 3.

# %%
total_units_sold = np.sum(units_sold)
average_revenue_per_unit = total_sales / total_units_sold
print(f"Average revenue per unit sold for the month: {average_revenue_per_unit:.2f}")
# Out:
# Average revenue per unit sold for the month: 323.47

# %%
days_sales_above_target = np.sum(sales_revenue > 1200)
print(f"Number of days sales revenue above 1200: {days_sales_above_target}")
# Out:
# Number of days sales revenue above 1200: 14

# %%
units_sold_blow_target = np.sum(units_sold[sales_revenue < 900])
print(f"Units sold when sales revenue was below 900: {units_sold_blow_target}")
# Out:
# Units sold when sales revenue was below 900: 896

# %%
weekly_sales_revenue = np.array([])
for week in range(4):
    start = week * 7
    end = start + 7
    week_total = np.sum(sales_revenue[start:end])
    weekly_sales_revenue = np.append(weekly_sales_revenue, week_total)
print("Total sales revenue for each full week:", weekly_sales_revenue)
# Out:
# Total sales revenue for each full week: [173461.97 102926.54 225126.64  63907.84]
