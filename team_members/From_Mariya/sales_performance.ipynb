# %%
# 7. Value counts and filtering examples

## Count of each store type
print("Store type distribution:")
print(df["Type"].value_counts())

## Filter high sales entries
high_sales = df[df["Weekly_Sales"] > 50000]
print("High sales entries (>50K):", high_sales.shape[0])
high_sales.head()
# Out:
# Store type distribution:
# Type
# A    215478
# B    163495
# C     42597
# Name: count, dtype: int64
# High sales entries (>50K): 32184
#      Store  Dept       Date  Weekly_Sales  IsHoliday_x  Temperature  \
# 8        1     1 2010-04-02      57258.43        False        62.27
# 46       1     1 2010-12-24      55931.23        False        52.33
# 63       1     1 2011-04-22      50510.31        False        72.99
# 106      1     1 2012-02-17      54060.10        False        45.32
# 113      1     1 2012-04-06      57592.12        False        70.43
#
#      Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 8         2.719        NaN        NaN        NaN        NaN        NaN
# 46        2.886        NaN        NaN        NaN        NaN        NaN
# 63        3.807        NaN        NaN        NaN        NaN        NaN
# 106       3.510    9873.33   11062.27       9.80    8409.31    3402.66
# ...

# %%
# 6. Concatenation Example

## Filter: First 2 months of 2010 and last 2 months of 2010
early_2010 = df[(df["Date"] >= "2010-01-01") & (df["Date"] <= "2010-02-28")]
late_2010 = df[(df["Date"] >= "2010-11-01") & (df["Date"] <= "2010-12-31")]

## Concatenate them vertically
combined = pd.concat([early_2010, late_2010])

print("Combined shape:", combined.shape)
combined.head()
# Out:
# Combined shape: (38306, 17)
#      Store  Dept       Date  Weekly_Sales  IsHoliday_x  Temperature  \
# 0        1     1 2010-02-05      24924.50        False        42.31
# 1        1     1 2010-02-12      46039.49         True        38.51
# 2        1     1 2010-02-19      41595.55        False        39.93
# 3        1     1 2010-02-26      19403.54        False        46.63
# 143      1     2 2010-02-05      50605.27        False        42.31
#
#      Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0         2.572        NaN        NaN        NaN        NaN        NaN
# 1         2.548        NaN        NaN        NaN        NaN        NaN
# 2         2.514        NaN        NaN        NaN        NaN        NaN
# 3         2.561        NaN        NaN        NaN        NaN        NaN
# 143       2.572        NaN        NaN        NaN        NaN        NaN
#
#             CPI  Unemployment  IsHoliday_y Type    Size
# ...

# %%
# 5. GroupBy Examples

## Total sales by Store
sales_by_store = df.groupby("Store")["Weekly_Sales"].sum().sort_values(ascending=False)
print("Total sales by store:")
display(sales_by_store)

## Total sales by Department
sales_by_dept = df.groupby("Dept")["Weekly_Sales"].sum().sort_values(ascending=False)
print("Total sales by department:")
display(sales_by_dept)

## Average weekly sales by Store Type
avg_sales_by_type = df.groupby("Type")["Weekly_Sales"].mean()
print("Average weekly sales by store type:")
display(avg_sales_by_type)

## Sales comparison: Holidays vs Non-Holidays
sales_holiday = df.groupby("IsHoliday")["Weekly_Sales"].agg(["mean", "sum", "count"])
print("Holiday vs Non-Holiday sales:")
display(sales_holiday)

# %%
# 4. Merge Datasets

## a. Merge train + features on Store and Date
df = pd.merge(train, features, on=["Store", "Date"], how="left")

## b. Merge with stores on Store
df = pd.merge(df, stores, on="Store", how="left")

df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday_x  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50        False        42.31       2.572
# 1      1     1 2010-02-12      46039.49         True        38.51       2.548
# 2      1     1 2010-02-19      41595.55        False        39.93       2.514
# 3      1     1 2010-02-26      19403.54        False        46.63       2.561
# 4      1     1 2010-03-05      21827.90        False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment  IsHoliday_y Type    Size
# ...

# %%
# 3. Convert Date columns to datetime

train["Date"] = pd.to_datetime(train["Date"])
features["Date"] = pd.to_datetime(features["Date"])

# %%
# 2. Check for nulls and get data overview


print("Missing values in train:\n", train.isnull().sum())
print("\nMissing values in features:\n", features.isnull().sum())
print("\nMissing values in stores:\n", stores.isnull().sum())

# Info and describe
train.info()
features.describe()
# Out:
# Missing values in train:
#  Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64
#
# Missing values in features:
#  Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64
#
# Missing values in stores:
#  Store    0
# Type     0
# Size     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# ...

# %%
# 1. Import Libraries


import pandas as pd

train = pd.read_csv(r"C:\Users\admin\OneDrive\Desktop\ML\machine-learning-code-orbit\team_members\From_Mariya\data\train.csv")
features = pd.read_csv(r"C:\Users\admin\OneDrive\Desktop\ML\machine-learning-code-orbit\team_members\From_Mariya\data\features.csv")
stores = pd.read_csv(r"C:\Users\admin\OneDrive\Desktop\ML\machine-learning-code-orbit\team_members\From_Mariya\data\stores.csv")

print("Train data:")
display(train.head())

print("Features data:")
display(features.head())

print("Stores data:")
display(stores.head())
# Out:
# Train data:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False
# Features data:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# ...
