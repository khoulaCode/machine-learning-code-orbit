# %%
# 5. Plot Grouped Results

## C. Plot Total Exports Over All Years
top10_exports = grouped.sort_values(by="Exports of goods and services", ascending=False).head(10)

plt.figure()
plt.bar(top10_exports["Country"], top10_exports["Exports of goods and services"])
plt.title("Top 10 Countries by Total Exports (1970–2021)")
plt.ylabel("Total Exports (USD)")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 5. Plot Grouped Results

## B. Plot Max Import of Goods
top10_imports = grouped.sort_values(by="Imports of goods and services", ascending=False).head(10)

plt.figure()
plt.bar(top10_imports["Country"], top10_imports["Imports of goods and services"])
plt.title("Top 10 Countries by Max Imports of Goods")
plt.ylabel("Max Import of Goods (USD)")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 5. Plot Grouped Results

## A. Plot Mean GDP per Capita
top10_gdp_pc = grouped.sort_values(by="Per capita GNI", ascending=False).head(10)

plt.figure()
plt.bar(top10_gdp_pc["Country"], top10_gdp_pc["Per capita GNI"])
plt.title("Top 10 Countries by Mean GDP per Capita")
plt.ylabel("Mean GDP per Capita (USD)")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 4. Group by country and Calculate Required Values


metrics = {
    "Per capita GNI": "mean",
    "Imports of goods and services": "max",
    "Exports of goods and services": "sum"
}

grouped = df.groupby("Country").agg(metrics).reset_index()

print("\nGrouped Country-Level Metrics (first 10 rows):")
print(grouped.head(10))
# Out:
# Grouped Country-Level Metrics (first 10 rows):
#                  Country  Per capita GNI  Imports of goods and services  \
# 0           Afghanistan       313.403846                   8.251464e+09
# 1               Albania      2052.807692                   8.016544e+09
# 2               Algeria      2530.923077                   6.826238e+10
# 3               Andorra     26166.826923                   1.255394e+09
# 4                Angola      1527.615385                   5.047163e+10
# 5              Anguilla     11254.288462                   4.063413e+08
# 6   Antigua and Barbuda      8226.442308                   9.522079e+08
# 7             Argentina      6353.826923                   9.026022e+10
# 8               Armenia      2324.937500                   7.458380e+09
# 9                 Aruba     15926.403846                   2.425195e+09
#
#    Exports of goods and services
# 0                   6.354409e+10
# 1                   7.889164e+10
# ...

# %%
# 3. Countries with Household Consumption Expenditure in Most Recent Year


latest_year = df["Year"].max()
household_col = [col for col in df.columns if "household consumption" in col.lower()][0]
latest_consumption = df[df["Year"] == latest_year][["Country", household_col]].dropna()
latest_consumption = latest_consumption.sort_values(by=household_col, ascending=False)

print(f"\nCountries with Household Consumption Expenditure in {latest_year}:")
print(latest_consumption.head(10))  ##Show top 10

plt.figure()
plt.bar(latest_consumption["Country"].head(10), latest_consumption[household_col].head(10))
plt.title(f"Top 10 Household Consumption Expenditure in {latest_year}")
plt.ylabel("Household Consumption Expenditure")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Countries with Household Consumption Expenditure in 2021:
#                 Country  \
# 10144    United States
# 1999             China
# 4680             Japan
# 3484           Germany
# 4212             India
# 10008   United Kingdom
# 3140            France
# 4524             Italy
# 1635            Canada
# 1083            Brazil
#
#        Household consumption expenditure (including Non-profit institutions serving households)
# 10144                                       1.590000e+13
# 1999                                        6.800000e+12
# 4680                                        2.660000e+12
# 3484                                        2.100000e+12
# 4212                                        1.910000e+12
# 10008                                       1.890000e+12
# 3140                                        1.560000e+12
# 4524                                        1.220000e+12
# 1635                                        1.080000e+12
# ...

# %%
# 2. Top 5 coutries by average GDP


top5_gdp = (
    df.groupby("Country")["Gross Domestic Product (GDP)"]
    .mean()
    .sort_values(ascending=False)  ##This step to sort the countries form highest to lowest GDP .
    .head(5) ##This to choose only the TOP 5.
    .reset_index(name="Average GDP (USD)")
)

print("Top 5 Countries by Average GDP:")
print(top5_gdp)

plt.figure()
plt.bar(top5_gdp["Country"], top5_gdp["Average GDP (USD)"]) ##(x "country", y "avg gdp values").
plt.title("Top 5 Countries by Average GDP (1970–2021)")
plt.ylabel("Average GDP (USD)")
plt.xlabel("Country")
plt.xticks(rotation=45) ##This controls how the x-axis labels (the country names) are displayed.
plt.tight_layout() ##This to get more smacing in x-axis and to ensure nothing is cutting off.
plt.show()
# Out:
# Top 5 Countries by Average GDP:
#             Country  Average GDP (USD)
# 0    United States        9.321346e+12
# 1            Japan        3.417731e+12
# 2            China        3.372873e+12
# 3          Germany        2.095904e+12
# 4   United Kingdom        1.515096e+12

# %%
# 1. Load the dataset


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\admin\OneDrive\Desktop\ML\machine-learning-code-orbit\From_Mariya\Data\Global Economy Indicators.csv")

df.columns = [c.strip() for c in df.columns]
