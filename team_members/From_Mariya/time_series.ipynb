# %%
import matplotlib.pyplot as plt

daily_avg.plot(title='Daily Average Power Usage')
plt.ylabel('Global Active Power (kilowatts)')
plt.xlabel('Date')

plt.show()

# %%
daily_avg = df['Global_active_power'].resample('D').mean()
weekly_sum = df['Global_active_power'].resample('W').sum()
monthly_avg = df['Global_active_power'].resample('M').mean()

print("Daily Avg:\n", daily_avg.head())
print("Weekly Sum:\n", weekly_sum.head())
print("Monthly Avg:\n", monthly_avg.head())
# Out:
# Daily Avg:
#  Datetime
# 2006-12-16    3.053475
# 2006-12-17    2.354486
# 2006-12-18    1.530435
# 2006-12-19    1.157079
# 2006-12-20    1.545658
# Freq: D, Name: Global_active_power, dtype: float64
# Weekly Sum:
#  Datetime
# 2006-12-17     4599.636
# 2006-12-24    17477.128
# 2006-12-31    19736.518
# 2007-01-07    14961.068
# 2007-01-14    16176.334
# Freq: W-SUN, Name: Global_active_power, dtype: float64
# Monthly Avg:
#  Datetime
# 2006-12-31    1.901295
# 2007-01-31    1.546034
# 2007-02-28    1.401084
# 2007-03-31    1.318627
# 2007-04-30    0.891189
# Freq: ME, Name: Global_active_power, dtype: float64
# C:\Users\admin\AppData\Local\Temp\ipykernel_4556\800275325.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg = df['Global_active_power'].resample('M').mean()

# %%
jan_2007 = df.loc['2007-01']
print(jan_2007.head())

one_day = df.loc['2007-01-15']
print(one_day.head())
# Out:
#                      Global_active_power Global_reactive_power  Voltage  \
# Datetime
# 2007-01-01 00:00:00                2.580                 0.136  241.970
# 2007-01-01 00:01:00                2.552                 0.100  241.750
# 2007-01-01 00:02:00                2.550                 0.100  241.640
# 2007-01-01 00:03:00                2.550                 0.100  241.710
# 2007-01-01 00:04:00                2.554                 0.100  241.980
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# Datetime
# 2007-01-01 00:00:00           10.600          0.000          0.000
# 2007-01-01 00:01:00           10.400          0.000          0.000
# 2007-01-01 00:02:00           10.400          0.000          0.000
# 2007-01-01 00:03:00           10.400          0.000          0.000
# 2007-01-01 00:04:00           10.400          0.000          0.000
#
#                      Sub_metering_3
# Datetime
# 2007-01-01 00:00:00             0.0
# ...

# %%
df['Global_active_power'] = pd.to_numeric(df['Global_active_power'], errors='coerce')

df = df.dropna(subset=['Global_active_power'])

# %%
df['Datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], errors='coerce', dayfirst=True)
df.set_index('Datetime', inplace=True)
df.drop(columns=['Date', 'Time'], inplace=True)

print(df.head())
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# Datetime
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# Datetime
# 2006-12-16 17:24:00           18.400          0.000          1.000
# 2006-12-16 17:25:00           23.000          0.000          1.000
# 2006-12-16 17:26:00           23.000          0.000          2.000
# 2006-12-16 17:27:00           23.000          0.000          1.000
# 2006-12-16 17:28:00           15.800          0.000          1.000
#
#                      Sub_metering_3
# Datetime
# 2006-12-16 17:24:00            17.0
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\admin\OneDrive\Desktop\ML\machine-learning-code-orbit\From_Mariya\Data\household_power_consumption.txt", sep=";", low_memory=False)

print(df.head())
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0
