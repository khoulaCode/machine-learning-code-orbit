# %%
import numpy as np

# %%
sales = np.random.normal(100, 1000, size=30)
sales = np.round(sales, 2)
sales = np.clip(sales, 0, None)
print("Sales data for the month: ", sales)
# Out:
# Sales data for the month:  [ 632.98 1145.2     0.     18.74    0.      0.      0.      0.      0.
#  1727.67 2405.96 1495.65    0.      0.    814.43  405.92    0.      0.
#  1268.22  295.63 2344.16 1604.27    0.      0.      0.    600.41  779.88
#    79.55    0.      0.  ]

# %%
units_sold = np.random.randint(1, 100, size=30)
print("Units sold for the month: ", units_sold)
# Out:
# Units sold for the month:  [57 58  8 63 31  1 10 63  3 44 39 54 81 30 74 40 93 73 63 88 87 59 68 29
#  10 60 19 21 64 88]

# %%
sales_revenue = sales * units_sold
print("Sales revenue for the month: ", sales_revenue)
# Out:
# Sales revenue for the month:  [ 36079.86  66421.6       0.     1180.62      0.        0.        0.
#       0.        0.    76017.48  93832.44  80765.1       0.        0.
#   60267.82  16236.8       0.        0.    79897.86  26015.44 203941.92
#   94651.93      0.        0.        0.    36024.6   14817.72   1670.55
#       0.        0.  ]

# %%
data_2D = np.column_stack((sales_revenue, units_sold))
print(data_2D)
# Out:
# [[3.6079860e+04 5.7000000e+01]
#  [6.6421600e+04 5.8000000e+01]
#  [0.0000000e+00 8.0000000e+00]
#  [1.1806200e+03 6.3000000e+01]
#  [0.0000000e+00 3.1000000e+01]
#  [0.0000000e+00 1.0000000e+00]
#  [0.0000000e+00 1.0000000e+01]
#  [0.0000000e+00 6.3000000e+01]
#  [0.0000000e+00 3.0000000e+00]
#  [7.6017480e+04 4.4000000e+01]
#  [9.3832440e+04 3.9000000e+01]
#  [8.0765100e+04 5.4000000e+01]
#  [0.0000000e+00 8.1000000e+01]
#  [0.0000000e+00 3.0000000e+01]
#  [6.0267820e+04 7.4000000e+01]
#  [1.6236800e+04 4.0000000e+01]
#  [0.0000000e+00 9.3000000e+01]
#  [0.0000000e+00 7.3000000e+01]
#  [7.9897860e+04 6.3000000e+01]
#  [2.6015440e+04 8.8000000e+01]
#  [2.0394192e+05 8.7000000e+01]
#  [9.4651930e+04 5.9000000e+01]
#  [0.0000000e+00 6.8000000e+01]
#  [0.0000000e+00 2.9000000e+01]
#  [0.0000000e+00 1.0000000e+01]
#  [3.6024600e+04 6.0000000e+01]
#  [1.4817720e+04 1.9000000e+01]
#  [1.6705500e+03 2.1000000e+01]
#  [0.0000000e+00 6.4000000e+01]
#  [0.0000000e+00 8.8000000e+01]]

# %%
total_sales = np.sum(sales_revenue) 
print(f"Total sales revenue for the month: {total_sales:.2f}")
# Out:
# Total sales revenue for the month: 887821.74

# %%
sales_average = np.mean(units_sold)
sales_average = np.round(sales_average, 0)
sales_average = int(sales_average)
print(f"Average sales units_sold for the month: {sales_average}")
# Out:
# Average sales units_sold for the month: 49

# %%
maximum_sales = np.max(sales_revenue)
maximum_sales_index = np.argmax(sales_revenue)
print(f"Maximum sales revenue of {maximum_sales:.2f} occurred at index {maximum_sales_index}.")
# Out:
# Maximum sales revenue of 203941.92 occurred at index 20.

# %%
total_units_sold = np.sum(units_sold)
average_revenue_per_unit = total_sales / total_units_sold
print(f"Average revenue per unit sold for the month: {average_revenue_per_unit:.2f}")
# Out:
# Average revenue per unit sold for the month: 600.69

# %%
sales_above_target = np.sum(sales_revenue > 1200)
print(f"Number of days sales revenue above 1200: {sales_above_target}")
# Out:
# Number of days sales revenue above 1200: 14

# %%
units_sold_blow_target = np.sum(units_sold[sales_revenue < 900])
print(f"Units sold when sales revenue was below 900: {units_sold_blow_target}")
# Out:
# Units sold when sales revenue was below 900: 652

# %%
weekly_sales_revenue = np.array([])
for week in range(4):
    start = week * 7
    end = start + 7
    week_total = np.sum(sales_revenue[start:end])
    weekly_sales_revenue = np.append(weekly_sales_revenue, week_total)
print("Total sales revenue for each full week:", weekly_sales_revenue)
# Out:
# Total sales revenue for each full week: [103682.08 250615.02 386359.84 147164.8 ]
