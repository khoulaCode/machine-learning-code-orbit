# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = r"..\..\data\household_power_consumption.zip"
df = pd.read_csv(path, sep=';')
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10420\803169723.py:2: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=';')
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# ...

# %% [markdown]
# Convert to datetime, set datetime index

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Time'] = pd.to_datetime(df['Time'])
df.info()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10420\1823491321.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\admin\AppData\Local\Temp\ipykernel_10420\1823491321.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   datetime64[ns]
#  1   Time                   datetime64[ns]
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
# ...

# %% [markdown]
# Setting datetime index

# %%
df['Datetime'] = pd.to_datetime(df['Date'], ' ' , df['Time'])
df.set_index('Datetime')
df.head(5)
# Out:
#         Date                Time Global_active_power Global_reactive_power  \
# 0 2006-12-16 2025-07-13 17:24:00               4.216                 0.418
# 1 2006-12-16 2025-07-13 17:25:00               5.360                 0.436
# 2 2006-12-16 2025-07-13 17:26:00               5.374                 0.498
# 3 2006-12-16 2025-07-13 17:27:00               5.388                 0.502
# 4 2006-12-16 2025-07-13 17:28:00               3.666                 0.528
#
#    Voltage Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3  \
# 0  234.840           18.400          0.000          1.000            17.0
# 1  233.630           23.000          0.000          1.000            16.0
# 2  233.290           23.000          0.000          2.000            17.0
# 3  233.740           23.000          0.000          1.000            17.0
# 4  235.680           15.800          0.000          1.000            17.0
#
#     Datetime
# 0 2006-12-16
# 1 2006-12-16
# 2 2006-12-16
# ...

# %% [markdown]
# Time-based slicing df.loc['2020-01']

# %%
df_timebased = df.set_index('Datetime').loc['2006-12-16']
df_timebased.head(5)
# Out:
#                  Date                Time Global_active_power  \
# Datetime
# 2006-12-16 2006-12-16 2025-07-13 17:24:00               4.216
# 2006-12-16 2006-12-16 2025-07-13 17:25:00               5.360
# 2006-12-16 2006-12-16 2025-07-13 17:26:00               5.374
# 2006-12-16 2006-12-16 2025-07-13 17:27:00               5.388
# 2006-12-16 2006-12-16 2025-07-13 17:28:00               3.666
#
#            Global_reactive_power  Voltage Global_intensity Sub_metering_1  \
# Datetime
# 2006-12-16                 0.418  234.840           18.400          0.000
# 2006-12-16                 0.436  233.630           23.000          0.000
# 2006-12-16                 0.498  233.290           23.000          0.000
# 2006-12-16                 0.502  233.740           23.000          0.000
# 2006-12-16                 0.528  235.680           15.800          0.000
#
#            Sub_metering_2  Sub_metering_3
# Datetime
# 2006-12-16          1.000            17.0
# ...

# %% [markdown]
# Resampling (resample('M'), resample('W'))

# %%
df_resampled_month = df.set_index('Datetime').resample('M')
df_resampled_week = df.set_index('Datetime').resample('W')

print("Monthly resampled data:")
print(df_resampled_month)

print("\nWeekly resampled data:")
print(df_resampled_week)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10420\490558980.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_resampled_month = df.set_index('Datetime').resample('M')
# Monthly resampled data:
# DatetimeIndexResampler [freq=<MonthEnd>, axis=0, closed=right, label=right, convention=start, origin=start_day]
#
# Weekly resampled data:
# DatetimeIndexResampler [freq=<Week: weekday=6>, axis=0, closed=right, label=right, convention=start, origin=start_day]

# %%
df['Global_active_power'] = df['Global_active_power'].replace('?', np.nan).astype(float)
df['Global_reactive_power'] = df['Global_reactive_power'].replace('?', np.nan).astype(float)
df['Voltage'] = df['Voltage'].replace('?', np.nan).astype(float)
df['Global_intensity'] = df['Global_intensity'].replace('?', np.nan).astype(float)
df['Sub_metering_1'] = df['Sub_metering_1'].replace('?', np.nan).astype(float)
df['Sub_metering_2'] = df['Sub_metering_2'].replace('?', np.nan).astype(float)

# %%
plt.figure(figsize=(13, 6))
plt.plot(df['Datetime'], df['Global_active_power'], label='Global Active Power', color='blue')
plt.plot(df['Datetime'], df['Global_reactive_power'], label='Global Reactive Power', color='red')
plt.xlabel('Datetime')
plt.ylabel('Power (kW)')
plt.title('Global Active and Reactive Power Over Time')
plt.show()
