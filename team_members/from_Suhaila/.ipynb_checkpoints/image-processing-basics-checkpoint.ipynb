# %%
import numpy as np

# %%
image = np.random.randint(0, 256, (10, 10))
print(image)
# Out:
# [[216  57 251  33  97  98 251  37  34  28]
#  [ 83  90 127  95 121 129  31 208 232 178]
#  [ 39 168 106  55  57  45  91  39 184  44]
#  [  6 217  49   6 123 206  39 192  48  94]
#  [ 28 249  25 123 181   5 186  85  46  23]
#  [159  39  19 220 151  99 222 244 149  57]
#  [244  32 241 171 141 126 218 131  88  83]
#  [ 41 209 164   6 243 169 168 120 253 209]
#  [155 106   3 107 239 188 190 191 123 169]
#  [252 141 193 203 221 213 183  89  32  17]]

# %%
import matplotlib.pyplot as plt
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# </p1> matplotlib.pyplot.imshow() allows you to render an arry as an image, since it's gray scale we have to specify the colormap "gray" then we can display the image using plt.show() <p1/>

# %%
inv_image = 255 - image
plt.imshow(inv_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
threshold = 128
thresholded_image = (image > threshold).astype(np.uint8) * 255
plt.imshow(thresholded_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
crop_image = image[2:6, 2:6]
plt.imshow(crop_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
h_edges = np.zeros_like(image)
h_edges[:, :-1] = image[:, 1:] - image[:, :-1]
plt.imshow(h_edges, cmap='gray')
plt.axis('off')
plt.show()
