# %%
import numpy as np
import pandas as pd
PATH = r"../../data/laptopData.csv"
df = pd.read_csv(PATH)
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.drop(columns =['Unnamed: 0'], inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 112.1+ KB

# %%
df.isnull().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1273 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 119.3+ KB

# %%
df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', '17.3', '13.5', '12.5', '13',
#        '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '10.1'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\admin\AppData\Local\Temp\ipykernel_18072\901282791.py:1: SyntaxWarning: invalid escape sequence '\?'
#   df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
#     Company     TypeName Inches   ScreenResolution  \
# 208    Dell    Ultrabook   13.3  Full HD 1920x1080
# 476    Dell  Workstation      ?  Full HD 1920x1080
# 770    Dell     Notebook   15.6  Full HD 1920x1080
#
#                              Cpu   Ram     Memory                     Gpu  \
# 208   Intel Core i7 8550U 1.8GHz   8GB  256GB SSD  Intel UHD Graphics 620
# 476  Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD     Nvidia Quadro M1200
# 770   Intel Core i7 7500U 2.7GHz  16GB          ?      AMD Radeon R7 M445
#
#           OpSys  Weight        Price
# 208  Windows 10       ?   77202.7200
# 476  Windows 10  1.78kg  128298.2400
# 770  Windows 10   2.3kg   62938.0656

# %%
columns = ['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
           'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']

df.loc[770, columns]
# Out:
# Company                                   Dell
# TypeName                              Notebook
# Inches                                    15.6
# ScreenResolution             Full HD 1920x1080
# Cpu                 Intel Core i7 7500U 2.7GHz
# Ram                                       16GB
# Memory                                       ?
# Gpu                         AMD Radeon R7 M445
# OpSys                               Windows 10
# Weight                                   2.3kg
# Price                               62938.0656
# Name: 770, dtype: object

# %%
df.query('Company == "Dell" and TypeName == "Ultrabook" and ScreenResolution == "Full HD 1920x1080" and Cpu == "Intel Core i7 8550U 1.8GHz"')
# Out:
#     Company   TypeName Inches   ScreenResolution                         Cpu  \
# 208    Dell  Ultrabook   13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 344    Dell  Ultrabook   13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys Weight     Price
# 208  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10      ?  77202.72
# 344  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10  1.2kg  84129.12

# %%
df.loc[208,'Weight'] = df.loc[208,'Weight'].replace('?','1.2kg')

# %%
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1273 rows x 11 columns]

# %%
df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\admin\AppData\Local\Temp\ipykernel_18072\901282791.py:1: SyntaxWarning: invalid escape sequence '\?'
#   df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
#     Company     TypeName Inches   ScreenResolution  \
# 476    Dell  Workstation      ?  Full HD 1920x1080
# 770    Dell     Notebook   15.6  Full HD 1920x1080
#
#                              Cpu   Ram     Memory                  Gpu  \
# 476  Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD  Nvidia Quadro M1200
# 770   Intel Core i7 7500U 2.7GHz  16GB          ?   AMD Radeon R7 M445
#
#           OpSys  Weight        Price
# 476  Windows 10  1.78kg  128298.2400
# 770  Windows 10   2.3kg   62938.0656

# %%
df.query('Company == "Dell" and TypeName == "Workstation" and ScreenResolution == "Full HD 1920x1080" and Cpu == "Intel Core i7 7700HQ 2.8GHz"')
# Out:
#     Company     TypeName Inches   ScreenResolution  \
# 476    Dell  Workstation      ?  Full HD 1920x1080
# 869    Dell  Workstation   15.6  Full HD 1920x1080
#
#                              Cpu  Ram     Memory                  Gpu  \
# 476  Intel Core i7 7700HQ 2.8GHz  8GB  256GB SSD  Nvidia Quadro M1200
# 869  Intel Core i7 7700HQ 2.8GHz  8GB    1TB HDD   Nvidia Quadro M620
#
#           OpSys  Weight      Price
# 476  Windows 10  1.78kg  128298.24
# 869  Windows 10  2.23kg   94731.84

# %%
df.loc[476,'Inches'] = df.loc[476,'Inches'].replace('?','15.6')

# %%
df.loc[476]
# Out:
# Company                                    Dell
# TypeName                            Workstation
# Inches                                     15.6
# ScreenResolution              Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                         Nvidia Quadro M1200
# OpSys                                Windows 10
# Weight                                   1.78kg
# Price                                 128298.24
# Name: 476, dtype: object

# %%
df[df.astype(str).apply(lambda x: x.str.contains('/s')).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df.query('Company == "Dell" and TypeName == "Notebook" and ScreenResolution == "Full HD 1920x1080" and Cpu == "Intel Core i7 7500U 2.7GHz" and Ram == "16GB"')
# Out:
#      Company  TypeName Inches   ScreenResolution                         Cpu  \
# 235     Dell  Notebook   15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 770     Dell  Notebook   15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 1063    Dell  Notebook   15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
#
#        Ram     Memory                 Gpu       OpSys  Weight       Price
# 235   16GB  256GB SSD  AMD Radeon R7 M445       Linux  2.36kg  47898.7200
# 770   16GB          ?  AMD Radeon R7 M445  Windows 10   2.3kg  62938.0656
# 1063  16GB    2TB HDD  AMD Radeon R7 M445  Windows 10  2.32kg  52746.6672

# %%
df.loc[770,'Memory'] = df.loc[476,'Memory'].replace('?','2TB HDD')

# %%
df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\admin\AppData\Local\Temp\ipykernel_18072\901282791.py:1: SyntaxWarning: invalid escape sequence '\?'
#   df[df.astype(str).apply(lambda x: x.str.contains('\?')).any(axis=1)]
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1273 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 151.6+ KB

# %%
df['Inches'] = df['Inches'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 151.6+ KB

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df.rename(columns = {'Ram' : 'Ram(GB)'},inplace=True)

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.rename(columns= {'Weight' : 'Weight(kg)'}, inplace=True)

# %%
df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
#df['Memory'].str.contains('kg', na=False).sum()

# %%
df['ID'] = range(1, len(df) + 1)
df.set_index('ID', inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram(GB)',
#        'Memory', 'Gpu', 'OpSys', 'Weight(kg)', 'Price'],
#       dtype='object')

# %%
df['Ram(GB)'] = df['Ram(GB)'].astype(int)

# %%
df['Weight(kg)'] = df['Weight(kg)'].astype(float)

# %%
from sklearn.preprocessing import MinMaxScaler , StandardScaler



scaler = MinMaxScaler()

columns_to_scale = ['Inches', 'Price','Ram(GB)','Weight(kg)']

df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# scaled_df = pd.DataFrame(scaled_data, columns=columns_to_scale)

df.head()
# Out:
#    Company   TypeName    Inches                    ScreenResolution  \
# ID
# 1    Apple  Ultrabook  0.125490  IPS Panel Retina Display 2560x1600
# 2    Apple  Ultrabook  0.125490                            1440x900
# 3       HP   Notebook  0.215686                   Full HD 1920x1080
# 4    Apple  Ultrabook  0.207843  IPS Panel Retina Display 2880x1800
# 5    Apple  Ultrabook  0.125490  IPS Panel Retina Display 2560x1600
#
#                            Cpu   Ram(GB)               Memory  \
# ID
# 1         Intel Core i5 2.3GHz  0.111111            128GB SSD
# 2         Intel Core i5 1.8GHz  0.111111  128GB Flash Storage
# 3   Intel Core i5 7200U 2.5GHz  0.111111            256GB SSD
# 4         Intel Core i7 2.7GHz  0.238095            512GB SSD
# 5         Intel Core i5 3.1GHz  0.111111            256GB SSD
#
#                              Gpu  OpSys  Weight(kg)     Price
# ID
# 1   Intel Iris Plus Graphics 640  macOS    0.123408  0.196741
# 2         Intel HD Graphics 6000  macOS    0.120705  0.122353
# 3          Intel HD Graphics 620  No OS    0.167553  0.067679
# 4             AMD Radeon Pro 455  macOS    0.164850  0.398895
# 5   Intel Iris Plus Graphics 650  macOS    0.123408  0.275038

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 1 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram(GB)           1273 non-null   float64
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight(kg)        1273 non-null   float64
#  10  Price             1273 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 119.3+ KB

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram(GB)             0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight(kg)          0
# Price               0
# dtype: int64

# %%
df
# Out:
#      Company            TypeName    Inches  \
# ID
# 1      Apple           Ultrabook  0.125490
# 2      Apple           Ultrabook  0.125490
# 3         HP            Notebook  0.215686
# 4      Apple           Ultrabook  0.207843
# 5      Apple           Ultrabook  0.125490
# ...      ...                 ...       ...
# 1269  Lenovo  2 in 1 Convertible  0.152941
# 1270  Lenovo  2 in 1 Convertible  0.125490
# 1271  Lenovo            Notebook  0.152941
# 1272      HP            Notebook  0.215686
# 1273    Asus            Notebook  0.215686
#
#                                 ScreenResolution  \
# ID
# 1             IPS Panel Retina Display 2560x1600
# 2                                       1440x900
# 3                              Full HD 1920x1080
# 4             IPS Panel Retina Display 2880x1800
# 5             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269   IPS Panel Full HD / Touchscreen 1920x1080
# 1270  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1271                                    1366x768
# 1272                                    1366x768
# 1273                                    1366x768
#
#                                        Cpu   Ram(GB)               Memory  \
# ID
# 1                     Intel Core i5 2.3GHz  0.111111            128GB SSD
# 2                     Intel Core i5 1.8GHz  0.111111  128GB Flash Storage
# 3               Intel Core i5 7200U 2.5GHz  0.111111            256GB SSD
# 4                     Intel Core i7 2.7GHz  0.238095            512GB SSD
# 5                     Intel Core i5 3.1GHz  0.111111            256GB SSD
# ...                                    ...       ...                  ...
# 1269            Intel Core i7 6500U 2.5GHz  0.047619            128GB SSD
# 1270            Intel Core i7 6500U 2.5GHz  0.238095            512GB SSD
# 1271  Intel Celeron Dual Core N3050 1.6GHz  0.015873   64GB Flash Storage
# 1272            Intel Core i7 6500U 2.5GHz  0.079365              1TB HDD
# 1273  Intel Celeron Dual Core N3050 1.6GHz  0.047619            500GB HDD
#
#                                Gpu       OpSys  Weight(kg)     Price
# ID
# 1     Intel Iris Plus Graphics 640       macOS    0.123408  0.196741
# 2           Intel HD Graphics 6000       macOS    0.120705  0.122353
# 3            Intel HD Graphics 620       No OS    0.167553  0.067679
# 4               AMD Radeon Pro 455       macOS    0.164850  0.398895
# 5     Intel Iris Plus Graphics 650       macOS    0.123408  0.275038
# ...                            ...         ...         ...       ...
# 1269         Intel HD Graphics 520  Windows 10    0.162147  0.078312
# 1270         Intel HD Graphics 520  Windows 10    0.117101  0.223629
# 1271             Intel HD Graphics  Windows 10    0.135120  0.009283
# 1272            AMD Radeon R5 M330  Windows 10    0.197283  0.099578
# 1273             Intel HD Graphics  Windows 10    0.198184  0.032911
#
# [1273 rows x 11 columns]

# %%
df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
df['Memory'].str.split()
# Out:
# ID
# 1                  [128GB, SSD]
# 2       [128GB, Flash, Storage]
# 3                  [256GB, SSD]
# 4                  [512GB, SSD]
# 5                  [256GB, SSD]
#                  ...
# 1269               [128GB, SSD]
# 1270               [512GB, SSD]
# 1271     [64GB, Flash, Storage]
# 1272                 [1TB, HDD]
# 1273               [500GB, HDD]
# Name: Memory, Length: 1273, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 1 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram(GB)           1273 non-null   float64
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight(kg)        1273 non-null   float64
#  10  Price             1273 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 119.3+ KB

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram(GB)',
#        'Memory', 'Gpu', 'OpSys', 'Weight(kg)', 'Price'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
columns = ['Company','TypeName','ScreenResolution','Cpu','Memory', 'Gpu', 'OpSys']
for col in columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head(10)
# Out:
#     Company  TypeName    Inches  ScreenResolution  Cpu   Ram(GB)  Memory  Gpu  \
# ID
# 1         1         4  0.125490                23   65  0.111111       4   58
# 2         1         4  0.125490                 1   63  0.111111       2   51
# 3         7         3  0.215686                 8   74  0.111111      16   53
# 4         1         4  0.207843                25   85  0.238095      29    9
# 5         1         4  0.125490                23   67  0.111111      16   59
# 6         0         3  0.215686                 0   14  0.047619      26   17
# 7         1         4  0.207843                25   84  0.238095      15   60
# 8         1         4  0.125490                 1   63  0.111111      15   51
# 9         2         4  0.152941                 8  106  0.238095      29   98
# 10        0         4  0.152941                15   83  0.111111      16   61
#
#     OpSys  Weight(kg)     Price
# ID
# 1       8    0.123408  0.196741
# 2       8    0.120705  0.122353
# 3       4    0.167553  0.067679
# 4       8    0.164850  0.398895
# 5       8    0.123408  0.275038
# 6       5    0.189175  0.038143
# 7       3    0.183769  0.331809
# 8       8    0.120705  0.166194
# 9       5    0.117101  0.222954
# 10      5    0.144129  0.100591
