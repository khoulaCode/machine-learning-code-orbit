# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
np.random.seed(42)

# %%
num_user = np.random.rand(100,1) * 100 
cpu_utiliation = 2 * num_user + 5 + np.random.randn(100,1) * 10

# split data into training and testing sets

X_train,X_test,y_train,y_test = train_test_split(num_user , cpu_utiliation , test_size=0.2, random_state=42)

# %%
# 3. generate and train the linear regression model 
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(X_test)

# %%
# evaluation for this model (metrix )
mae = mean_absolute_error(y_test,y_predict)
mse = mean_squared_error(y_test,y_predict)
rmse = np.sqrt(mse) # note : (rmse) ()
r2 = r2_score(y_test,y_predict)

print("slope : ",coff)
print("mae : ",mae)
print("mse : ",mse)
print("rmse : ",rmse)
print("r2 : ",r2)
# Out:
# mae :  5.913425779189788
# mse :  65.36995137170024
# rmse :  8.085168605026134
# r2 :  0.9825431689004598

# %%
#hyperparemeter : it will change the model (how to solve the error, ARGUMENTS RETLEATED TO GENERALIZATION)
# paremeter which the model will learn when u do .fit

# %% [markdown]
# # polynomial function
# equation have x^3 + x^2 + 2x + 1
#
# polynimial for carved line not like linear where u have straight line in chart
#
# in leaner we have y and X
# in polynomial we have y,X,X^2

# %%
from sklearn.preprocessing import PolynomialFeatures

# Initialize the Linear Regression model
model_poly = LinearRegression()

# Create polynomial features transformer (degree 2 as example)
poly_feature = PolynomialFeatures(degree=2)

# Fit and transform training features
X_train_poly = poly_feature.fit_transform(X_train)

# Transform test features
X_test_poly = poly_feature.transform(X_test)

# Fit the model on polynomial features
model_poly.fit(X_train_poly, y_train)

# Predict on test set (optional)
y_pred_poly = model_poly.predict(X_test_poly)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.preprocessing import PolynomialFeatures
#       3 # Initialize the Linear Regression model
#       4 model_poly = LinearRegression()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ...

# %% [markdown]
# type :
# # dession tree regression
# # random forst regression
# # Support vector machine (SVM)
#
# ( types of linear regression)
# # redige regression
# # lasso regression

# %% [markdown]
# loop > 1 - min error > Optemization
#
# optimization > 1\n (y-y)^2
#
# lasso regression is also called ( L1 normal)
# note : || w || (W) >> is weights
# 1\n (y-y)^2 + || w ||
# lasso(alpha=1,max_iter=1000)
# y = w0 +w1x1 + w2x2 ...
#
# ridge regrssion is also called (L2 norm)
# note : ||w||^2
#
# when we will use those lesso and redige:
# r2 > is hight in train
# r2 > is less in test
#
# if the difference more big we should use some reglization like lesso or ridge
#
# builindg a model to fit test more

# %% [markdown]
# # Dession tree regression
# example : if the weight is less than or equal to 15g
# ether true or false
#
# if its true (weight <= 10>)
# we have ture and false
# if its true (cal = 150c) this is Y and we call it leaf
# it its false (cal = 170)
#
# leaf who have dession

# %% [markdown]
# # Random forst regression
# multiple dession trees , each one has a small dession tree
#
# the idea is to build weak dessions tree
#
# random forst it avoids over fitting and preform very well
# random forst is ensambles
#
# like XGboost (is usuful and used alot) and random forst

# %% [markdown]
# # SVM (Support Vector Machines)
# its a two vector like a border ( these vector depends on data or characterstics all the value will be in specific range so we can use hard margin)
# who let outliers it calls soft margin , if not its called hard margin
#
# karnel > let the svm to be not linear
# svm has build-in karnel
