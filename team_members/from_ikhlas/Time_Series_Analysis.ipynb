# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\admin\Downloads\archive (3)\household_power_consumption.txt"
df = pd.read_csv(path, sep=';')
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_3800\815327556.py:2: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=';')
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# ...

# %%
#Date and time set
df['Date_time'] = pd.to_datetime(df['Date'] +' '+ df['Time'], format='%d/%m/%Y %H:%M:%S')
df.set_index('Date_time', inplace = True)
df
# Out:
#                            Date      Time Global_active_power  \
# Date_time
# 2006-12-16 17:24:00  16/12/2006  17:24:00               4.216
# 2006-12-16 17:25:00  16/12/2006  17:25:00               5.360
# 2006-12-16 17:26:00  16/12/2006  17:26:00               5.374
# 2006-12-16 17:27:00  16/12/2006  17:27:00               5.388
# 2006-12-16 17:28:00  16/12/2006  17:28:00               3.666
# ...                         ...       ...                 ...
# 2010-11-26 20:58:00  26/11/2010  20:58:00               0.946
# 2010-11-26 20:59:00  26/11/2010  20:59:00               0.944
# 2010-11-26 21:00:00  26/11/2010  21:00:00               0.938
# 2010-11-26 21:01:00  26/11/2010  21:01:00               0.934
# 2010-11-26 21:02:00  26/11/2010  21:02:00               0.932
#
#                     Global_reactive_power  Voltage Global_intensity  \
# Date_time
# 2006-12-16 17:24:00                 0.418  234.840           18.400
# ...

# %%
df.drop(columns=['Date','Time'], inplace=True)
df
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# Date_time
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
# ...                                 ...                   ...      ...
# 2010-11-26 20:58:00               0.946                   0.0   240.43
# 2010-11-26 20:59:00               0.944                   0.0    240.0
# 2010-11-26 21:00:00               0.938                   0.0   239.82
# 2010-11-26 21:01:00               0.934                   0.0    239.7
# 2010-11-26 21:02:00               0.932                   0.0   239.55
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# Date_time
# ...

# %%
#slicing 
january2010 = df.loc['2010-01']
print(january2010)
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# Date_time
# 2010-01-01 00:00:00               1.790                 0.236  240.650
# 2010-01-01 00:01:00               1.780                 0.234  240.070
# 2010-01-01 00:02:00               1.780                 0.234  240.150
# 2010-01-01 00:03:00               1.746                 0.186  240.260
# 2010-01-01 00:04:00               1.686                 0.102  240.120
# ...                                 ...                   ...      ...
# 2010-01-31 23:55:00               0.724                 0.000  247.540
# 2010-01-31 23:56:00               0.584                 0.000  247.160
# 2010-01-31 23:57:00               0.426                 0.000  247.430
# 2010-01-31 23:58:00               0.248                 0.000  247.100
# 2010-01-31 23:59:00               0.324                 0.000  248.560
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# Date_time
# ...

# %%
#resampling
#monthly avg consumption
df['Global_active_power'] = pd.to_numeric(df['Global_active_power'], errors='coerce')
montly_avg_consm = df['Global_active_power'].resample('M').mean()
montly_avg_consm
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_3800\1056884039.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   montly_avg_consm = df['Global_active_power'].resample('M').mean()
# Date_time
# 2006-12-31    1.901295
# 2007-01-31    1.546034
# 2007-02-28    1.401084
# 2007-03-31    1.318627
# 2007-04-30    0.891189
# 2007-05-31    0.985862
# 2007-06-30    0.826814
# 2007-07-31    0.667367
# 2007-08-31    0.764186
# 2007-09-30    0.969318
# 2007-10-31    1.103911
# 2007-11-30    1.294473
# 2007-12-31    1.626474
# 2008-01-31    1.459920
# 2008-02-29    1.181384
# 2008-03-31    1.245337
# 2008-04-30    1.115972
# 2008-05-31    1.024281
# 2008-06-30    0.994096
# 2008-07-31    0.794781
# 2008-08-31    0.276488
# 2008-09-30    0.987680
# 2008-10-31    1.136768
# 2008-11-30    1.387066
# 2008-12-31    1.275189
# 2009-01-31    1.410202
# 2009-02-28    1.247568
# 2009-03-31    1.226735
# 2009-04-30    1.140690
# 2009-05-31    1.012856
# ...

# %%
weekly_avg_consm = df['Global_active_power'].resample('W').mean()
weekly_avg_consm
# Out:
# Date_time
# 2006-12-17    2.505248
# 2006-12-24    1.734186
# 2006-12-31    1.958376
# 2007-01-07    1.484233
# 2007-01-14    1.604954
#                 ...
# 2010-10-31    0.958963
# 2010-11-07    1.154565
# 2010-11-14    1.335928
# 2010-11-21    1.107106
# 2010-11-28    1.186756
# Freq: W-SUN, Name: Global_active_power, Length: 207, dtype: float64

# %%
daily_avg_consm = df['Global_active_power'].resample('D').mean()
daily_avg_consm
# Out:
# Date_time
# 2006-12-16    3.053475
# 2006-12-17    2.354486
# 2006-12-18    1.530435
# 2006-12-19    1.157079
# 2006-12-20    1.545658
#                 ...
# 2010-11-22    1.417733
# 2010-11-23    1.095511
# 2010-11-24    1.247394
# 2010-11-25    0.993864
# 2010-11-26    1.178230
# Freq: D, Name: Global_active_power, Length: 1442, dtype: float64

# %%
#Plotting 
plt.figure(figsize=(6,6))
plt.plot(montly_avg_consm, color = 'green')
plt.title('Monthly AVG Global Active Power Consumption')
plt.xlabel('Date')
plt.ylabel('Global Active Power')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.plot(weekly_avg_consm, color = 'yellow')
plt.title('Weekly AVG Global Active Power Consumption')
plt.xlabel('Date')
plt.ylabel('Global Active Power')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(9,9))
plt.plot(daily_avg_consm, color = 'maroon')
plt.title('Daily AVG Global Active Power Consumption')
plt.xlabel('Date')
plt.ylabel('Global Active Power')
plt.grid(True)
plt.show()
