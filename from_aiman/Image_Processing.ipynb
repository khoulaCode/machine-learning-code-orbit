# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Image Representation (Random 10x10)

# %%
pic_matrix = np.random.randint(0, 256, size=(10, 10), dtype=np.uint8)
print("1. Random Grayscale Image:\n", pic_matrix)
# Out:
# 1. Random Grayscale Image:
#  [[ 94  95 191 194 232 151 220 246  45  55]
#  [ 22 169 169 176 201 246 196 243 196 247]
#  [148 229 154 105  83 169  37  28   2 243]
#  [ 32 119 151  86 151  13 191 235   7  94]
#  [ 26 239  32 147 248 159  31 146  99  42]
#  [ 33 142 220 104  84 225  98 126 117  16]
#  [ 40  41 156  11 115 186 134  81 238 226]
#  [  0 209 209  77 244 119  64 110  45  77]
#  [ 33  55  44  73 193  20 241   2  26 249]
#  [ 83  58  41 152 222 189 192 203 185 182]]

# %%
import matplotlib.pyplot as plt
plt.imshow(pic_matrix, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 2. Display the Image (Concept)

# %%
plt.imshow(pic_matrix, cmap='gray')
plt.colorbar()
plt.title("Grayscale Image Display")
plt.show()

# %% [markdown]
# # 3. Grayscale Inversion

# %%
inverse_gray = 255 - pic_matrix
print("\n2. Inverted Image:\n", inverse_gray)
# Out:
# 2. Inverted Image:
#  [[161 160  64  61  23 104  35   9 210 200]
#  [233  86  86  79  54   9  59  12  59   8]
#  [107  26 101 150 172  86 218 227 253  12]
#  [223 136 104 169 104 242  64  20 248 161]
#  [229  16 223 108   7  96 224 109 156 213]
#  [222 113  35 151 171  30 157 129 138 239]
#  [215 214  99 244 140  69 121 174  17  29]
#  [255  46  46 178  11 136 191 145 210 178]
#  [222 200 211 182  62 235  14 253 229   6]
#  [172 197 214 103  33  66  63  52  70  73]]

# %%
import matplotlib.pyplot as plt
plt.imshow(inverse_gray, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 4. Thresholding (Binary)

# %%
cutoff = 128
binary_output = np.where(pic_matrix < cutoff, 0, 255)
print("\n3. Binary Image (after thresholding):\n", binary_output)
# Out:
# 3. Binary Image (after thresholding):
#  [[  0   0 255 255 255 255 255 255   0   0]
#  [  0 255 255 255 255 255 255 255 255 255]
#  [255 255 255   0   0 255   0   0   0 255]
#  [  0   0 255   0 255   0 255 255   0   0]
#  [  0 255   0 255 255 255   0 255   0   0]
#  [  0 255 255   0   0 255   0   0   0   0]
#  [  0   0 255   0   0 255 255   0 255 255]
#  [  0 255 255   0 255   0   0   0   0   0]
#  [  0   0   0   0 255   0 255   0   0 255]
#  [  0   0   0 255 255 255 255 255 255 255]]

# %%
import matplotlib.pyplot as plt
plt.imshow(binary_output, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 5. Cropping (4x4 Center)

# %%
row_start = (pic_matrix.shape[0] - 4) // 2
col_start = (pic_matrix.shape[1] - 4) // 2
roi_crop = pic_matrix[row_start:row_start + 4, col_start:col_start + 4]
print("\n4. Cropped 4x4 Center:\n", roi_crop)
# Out:
# 4. Cropped 4x4 Center:
#  [[ 86 151  13 191]
#  [147 248 159  31]
#  [104  84 225  98]
#  [ 11 115 186 134]]

# %%
import matplotlib.pyplot as plt
plt.imshow(roi_crop, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 6. Edge Detection (Basic Horizontal Convolution)

# %%
horizontal_edges = np.zeros_like(pic_matrix, dtype=int)
for row in range(pic_matrix.shape[0]):
    for col in range(pic_matrix.shape[1] - 1):
        horizontal_edges[row, col] = int(pic_matrix[row, col + 1]) - int(pic_matrix[row, col])
print("\n5. Horizontal Edge Detection:\n", horizontal_edges)
# Out:
# 5. Horizontal Edge Detection:
#  [[   1   96    3   38  -81   69   26 -201   10    0]
#  [ 147    0    7   25   45  -50   47  -47   51    0]
#  [  81  -75  -49  -22   86 -132   -9  -26  241    0]
#  [  87   32  -65   65 -138  178   44 -228   87    0]
#  [ 213 -207  115  101  -89 -128  115  -47  -57    0]
#  [ 109   78 -116  -20  141 -127   28   -9 -101    0]
#  [   1  115 -145  104   71  -52  -53  157  -12    0]
#  [ 209    0 -132  167 -125  -55   46  -65   32    0]
#  [  22  -11   29  120 -173  221 -239   24  223    0]
#  [ -25  -17  111   70  -33    3   11  -18   -3    0]]

# %%
import matplotlib.pyplot as plt
plt.imshow(horizontal_edges, cmap='gray')
plt.axis('off')
plt.show()
